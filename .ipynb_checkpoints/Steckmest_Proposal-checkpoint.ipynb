# %% [markdown]
# # Project Proposal for Data Bootcamp
#
#
# ## Alexandra Steckmest, Spring 2017

# %% [markdown]
# ** Question: A closer look at recidivism – how effective is it to invest money in rehabilitative forms of justice in prisons to achieve lower rates of recidivism?**

# %% [markdown]
# ## Background
#
# Different countries have vastly different criminal justice systems, ranging from ones that treat inmates as animals to ones that provide TV screens to every cell. Recently, there seems to be a belief that the more rehabilitative justice systems are “better” in the sense that it yields lower recidivism (rearrests), and therefore sees better results for prisoners after they are released. My project will look at Norway, which has one of the world’s lowest recidivism rates, as case study for a rehabilitative justice system and will attempt to determine whether making prisons more focused on rehabilitation actually decreases recidivism rates. Specifically, I will look at recidivism rates for various groups before and after a Storting (supreme legislature of Norway) message from 2008 that planned to make significant changes to bring down recidivism in Norwegian prisons.

# %% [markdown]
# ## Data
#
# All the data I will use comes from Statistics Norway and covers data between 2002 and 2010. I have gathered 3 data sets that I plan to use to analyse how recidivism changes over time:
#
# * The first data set shows 5-year recidivism rates for various types of principal offenses as well as offense at recidivism. For instance, the 2002 column will contain information that says: after 5 years of being released from a specific principal offense, what percentage of released prisoners get arrested again, and for what type of offense do they get arrested the second time? This data set supports my question because from it I will be able to tell which types of offenses are most and least affected by the changes
#
# * The second data set shows people charged in base year by number of years with recidivism (up to 5 years), and also shows recidivism for various age categories as well as sexes for each year. From this I hope to determine how recidivism varies across gender, age groups and, perhaps most interestingly, across years released. For instance, do most of the convicted criminals who reoffend do so in the first year after they are released or later? This supports my question because it will hopefully point to some specific effects of changes that are made, e.g. investments in rehabilitation seem to have a significant impact on women but not on men. This data may even allow me to get some insight into where the biggest need for rehabilitation lies.
#
# * The third data set shows the expenses for various aspects of the Norwegian Correctional Service between 2005 and 2012. This will allow me to see whether the 2008 message prompted an increase in the budget at the same time, and look at where the investments were impacted the most, monetarily.

# %%
# %matplotlib inline                     

import pandas as pd                    # data package
import matplotlib.pyplot as plt        # graphics module  
import datetime as dt                  # date and time module
import numpy as np                     # foundation for Pandas
import seaborn as sns                  # to make the graph look nicer

# %%
# importing the excel sheets…

path = '/Users/Alexandra/Documents/NYU/Data_Bootcamp/Project/'
file_budget = 'ssb_kriminalomsorgen.xlsx'
file_recid = 'SSB_recidivism.xlsx'

budget = pd.read_excel(path+file_budget)

recid_years = pd.read_excel(path+file_recid, sheetname='By_Years_Sex_Age')
recid_offense = pd.read_excel(path+file_recid, sheetname='By_Principal_Offense')

# %%
budget
# Out:
#    StatRes. The Correctional Services. Input by contents and time  Unnamed: 1  \
# 0                                                 NaN                     NaN
# 1                                                 NaN                  2005.0
# 2                 Operating expenditure (NOK million)                  2244.7
# 3                        Own production (NOK million)                  2208.5
# 4             Compensation of employees (NOK million)                  1641.0
# 5             Use of goods and services (NOK million)                   567.5
# 6                             Transfers (NOK million)                    36.2
# 7                     Capital formation (NOK million)                    86.3
# 8                     Total expenditure (NOK million)                  2331.1
# 9   Compensation of employees in per cent of own p...                    74.3
# 10  Use of goods and services in per cent of own p...                    25.7
# ...

# %%
budget = budget.rename(columns={'StatRes. The Correctional Services. Input by contents and time': 'Type of Spending'})

# %%
budget = budget.dropna(axis=0)

# %%
budget
# Out:
#                                      Type of Spending  Unnamed: 1  Unnamed: 2  \
# 2                 Operating expenditure (NOK million)      2244.7      2387.9
# 3                        Own production (NOK million)      2208.5      2351.4
# 4             Compensation of employees (NOK million)      1641.0      1726.5
# 5             Use of goods and services (NOK million)       567.5       624.8
# 6                             Transfers (NOK million)        36.2        36.5
# 7                     Capital formation (NOK million)        86.3       116.6
# 8                     Total expenditure (NOK million)      2331.1      2504.5
# 9   Compensation of employees in per cent of own p...        74.3        73.4
# 10  Use of goods and services in per cent of own p...        25.7        26.6
# 11  Estimated contributions to the Norwegian Publi...       198.9       212.1
#
#     Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8
# ...

# %%
fig, ax = plt.subplots()

budget.plot(ax=ax)

# %%
budget.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-dbc92e065364> in <module>()
# ----> 1 budget.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
budget = budget.drop([0, 1], axis=0)
# Out:
#    StatRes. Kriminalomsorgen. Ressursinnsats etter statistikkvariabel og tid  \
# 2                           Driftsutgifter (mill. kr)
# 3                           Egenproduksjon (mill. kr)
# 4                           Lønnskostnader (mill. kr)
# 5               Kjøp av varer og tjenester (mill. kr)
# 6                             Overføringer (mill. kr)
# 7                            Investeringer (mill. kr)
# 8                          Totale utgifter (mill. kr)
# 9          Lønnskostnader av egenproduksjon (prosent)
# 10  Kjøp av varer og tjenester av egenproduksjon (...
# 11  Beregnet premie til Statens Pensjonskasse (mil...
#
#     Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 2       2244.7      2387.9      2651.9      2869.8      3557.3      3859.7
# 3       2208.5      2351.4      2611.2      2844.3      3526.4      3805.6
# 4       1641.0      1726.5      1906.5      2099.7      2294.4      2429.9
# ...

# %%
# Out:
#                                                     Unnamed: 1  Unnamed: 2  \
# StatRes. Kriminalomsorgen. Ressursinnsats etter...
# NaN                                                        NaN         NaN
# NaN                                                     2005.0      2006.0
# Driftsutgifter (mill. kr)                               2244.7      2387.9
# Egenproduksjon (mill. kr)                               2208.5      2351.4
# Lønnskostnader (mill. kr)                               1641.0      1726.5
# Kjøp av varer og tjenester (mill. kr)                    567.5       624.8
# Overføringer (mill. kr)                                   36.2        36.5
# Investeringer (mill. kr)                                  86.3       116.6
# Totale utgifter (mill. kr)                              2331.1      2504.5
# Lønnskostnader av egenproduksjon (prosent)                74.3        73.4
# Kjøp av varer og tjenester av egenproduksjon (p...        25.7        26.6
# ...

# %%
recid_years
# Out:
#     Persons charged in base year by number of years with recidivism, sex, age, time and contents  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                      All years (0-5)
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# ...

# %%
recid_offense
# Out:
#     Persons charged in base year by type of principal offence, type of principal offence at recidivism, time and contents (5 year period)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                               All groups of offences
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# ...

# %% [markdown]
# These data sets require a lot of manipulation, particularly the two larger ones.

# %% [markdown]
# ## Figures
#
# In order to best convey my findings, I plan to use the following figures:
#
# * Line graphs for various aspects of recidivism over time, e.g. total 5-year recidivism rates, or 5-year recidivism rates for women v.s. men, or change in budget over time
#
# * Bar charts to show recidivism rates per period

# %% [markdown]
# **Comment:** I was not able to produce any reasonable graphs from this specific data set yet, as the data needs to first be manipulated.

# %% [markdown]
# ## Possible Conclusions

# %% [markdown]
# Obviously, there are a number of limitations to the conclusions I will be able to draw from this data. For instance, if there are changes after 2008 they may not be due directly to the message, and also is likely that even if there is a direct effect this may take a few years to see. However, I still hope to be able to convey some interesting facts and perhaps evaluations of a rehabilitative justice system.
